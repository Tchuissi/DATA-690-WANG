# %% [markdown]
# Assignment 07
#
# You can use the local Jupyter environment if you are not comfortable with Colab for this assignment.
#
# The first half of this assignment is a repeat of assignment 05.
#
# This gives you a chance to refresh.
#
# The second half is new and gives you a chance to perform additional practices.
#
# You also get a chance to use some of the Python libraries and techniques.
#
# You will unzip the zip file manually in preparation for this assignment.
#
# The link to the zip file is (you have already used it in your assignment 5):
#
# https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
#
# After unzipping, You will have all files in one folder named "CollegeScorecard_Raw_Data"
#
# The folder contains the yearly data files from 1996 to 2019 school years.
#
# if you are using your local environment, I suggest you create a new folder call "Assignment7" and place the Notebook file and the data folder under it.

# %%
# <1> 
# Import libraries

import pandas as pd

# %%
import os

# %%
# <2> 
# Display the current workin directory using os.getcwd()
# you would need to import a standard Python library called os which stands for operating system,
# so place that import statement in the previous cell.
# Since your notebook and your data files are not in # the same folder, 
# you want to make sure what is the current working folder and 
# how to access a data file in a different folder

os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Assignment 7\\CollegeScorecard_Raw_Data'

# %%
# <3> 
# os library has a method call listdir which generates a list of files in a directory/folder.
# use this method to assign the contents (list of file names) of the data folder to a variable and display it.
# # You can use ../ construct to traverse to the parent folder and then to another foloder parallel to the current folder

os.chdir('C:/Users/Lenovo/Assignment 7/CollegeScorecard_Raw_Data')   #change the current working directory
list_of_files= os.listdir()
print(list_of_files)
# Out:
# ['.DS_Store', 'Crosswalks.zip', 'data.yaml', 'FieldOfStudyData1415_1516_PP.csv', 'FieldOfStudyData1516_1617_PP.csv', 'MERGED1996_97_PP.csv', 'MERGED1997_98_PP.csv', 'MERGED1998_99_PP.csv', 'MERGED1999_00_PP.csv', 'MERGED2000_01_PP.csv', 'MERGED2001_02_PP.csv', 'MERGED2002_03_PP.csv', 'MERGED2003_04_PP.csv', 'MERGED2004_05_PP.csv', 'MERGED2005_06_PP.csv', 'MERGED2006_07_PP.csv', 'MERGED2007_08_PP.csv', 'MERGED2008_09_PP.csv', 'MERGED2009_10_PP.csv', 'MERGED2010_11_PP.csv', 'MERGED2011_12_PP.csv', 'MERGED2012_13_PP.csv', 'MERGED2013_14_PP.csv', 'MERGED2014_15_PP.csv', 'MERGED2015_16_PP.csv', 'MERGED2016_17_PP.csv', 'MERGED2017_18_PP.csv', 'MERGED2018_19_PP.csv']

# %%
# <4> 
# The folder contains files that are not the yearly data files
# write code to remove the unwanted files from the list vsriable 
# Note: don't remove/delete these files from the folder in your drive
# For example, use the file extension to only keep the csv files 
# or use the name patter - data file name begins with "MERGED"
# You can use the concept of list comprehension to write just 
# one line of code as well as using a for loop, your choice.

import glob
list_of_files=(glob.glob("MERGED*.csv"))
print(list_of_files, type(list_of_files))
# Out:
# ['MERGED1996_97_PP.csv', 'MERGED1997_98_PP.csv', 'MERGED1998_99_PP.csv', 'MERGED1999_00_PP.csv', 'MERGED2000_01_PP.csv', 'MERGED2001_02_PP.csv', 'MERGED2002_03_PP.csv', 'MERGED2003_04_PP.csv', 'MERGED2004_05_PP.csv', 'MERGED2005_06_PP.csv', 'MERGED2006_07_PP.csv', 'MERGED2007_08_PP.csv', 'MERGED2008_09_PP.csv', 'MERGED2009_10_PP.csv', 'MERGED2010_11_PP.csv', 'MERGED2011_12_PP.csv', 'MERGED2012_13_PP.csv', 'MERGED2013_14_PP.csv', 'MERGED2014_15_PP.csv', 'MERGED2015_16_PP.csv', 'MERGED2016_17_PP.csv', 'MERGED2017_18_PP.csv', 'MERGED2018_19_PP.csv'] <class 'list'>

# %%
len(list_of_files)
# Out:
# 23

# %%
# <5> 
# Now that you have a clean list of the yearly files, you want to loop through them
# and read them into a dataframe one at a time. You only load six columns: 
#["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"].
# You should use "usecols" option of Pandas to avoid reading unwanted columns.
# You also want to add a new column call "YEAR" to differentiate the data frames from each other.
# The YEAR variable should be yyyy format so tht you can convert them into integer.
# if you use the format yyyy-yy (such as 1997-98 school year), you will not be able to convert them directly to integer
# if you use scatter plot, the YEAR needs to be converted to integer or float. 
# 
# You would use an empty list and append the yearly dataframes to the list.
# After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a 
# new single data frame.
# Note: this exercise incorporates many techques we learned before
# - list (creating an empty, append an item to the list)
# - for loop 
# - read only the needed columns from a file (using usecols option)
# - add a new column to a data frame
# - concatenate multiple dataframes into a single one
# This exercise may appear a big challenging but it worths the effort. You will learn a lot and  love it. I promise.

#df_list=[]
#for files in list_of_files:
    #df=pd.read_csv("files.csv", usecols=["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])
#df_list.append('df')
#df_list

# %%
year=[]

for files in list_of_files:
    y=files[6:10]
    year.append(y)

year
# Out:
# ['1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018']

# %%
#path = r'C:\DRO\DCL_rawdata_files' # use your path
#all_files = glob.glob(path + "/*.csv")

#li = []

#for filename in all_files:
    #df = pd.read_csv(filename, index_col=None, header=0)
    #li.append(df)

#frame = pd.concat(li, axis=0, ignore_index=True)

list_of_files=(glob.glob("MERGED*.csv"))

df_list=[]
for files in list_of_files:
    df=pd.read_csv(files, index_col=None, header=0, usecols=["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])
    year=int(files[6:10])
    df['Year']=year
    df_list.append(df)
df_list
# Out:
# [      UNITID                                           INSTNM STABBR  REGION  \
#  0     100636               Community College of the Air Force     AL       0
#  1     100654                         Alabama A & M University     AL       5
#  2     100663              University of Alabama at Birmingham     AL       5
#  3     100672           ALABAMA AVIATION AND TECHNICAL COLLEGE     AL       5
#  4     100690                               Amridge University     AL       5
#  ...      ...                                              ...    ...     ...
#  7002  428347  American Institute of Medical-Dental Technology     UT       7
#  7003  428365          INSTITUTO DE ESTETICA Y BELLAZA MARUGIE     PR       9
#  7004  428374                           KEISER COLLEGE-DAYTONA     FL       5
#  7005  428392                        Klamath Community College     OR       8
#  7006  428444                     The Art Institute of Phoenix     AZ       6
#
# ...

# %%
final_df = pd.concat(df_list, axis=0, ignore_index=True)
final_df=final_df.fillna(0)  #replace NaN with 0
final_df
# Out:
#           UNITID                                    INSTNM STABBR  REGION  \
# 0         100636        Community College of the Air Force     AL     0.0
# 1         100654                  Alabama A & M University     AL     5.0
# 2         100663       University of Alabama at Birmingham     AL     5.0
# 3         100672    ALABAMA AVIATION AND TECHNICAL COLLEGE     AL     5.0
# 4         100690                        Amridge University     AL     5.0
# ...          ...                                       ...    ...     ...
# 163326  48511112         Georgia Military College - Dublin     GA     5.0
# 163327  48511113        Georgia Military College - Eastman     GA     5.0
# 163328  48616901  American College of Barbering - Florence     KY     5.0
# 163329  49005401      HCI College - Fort Lauderdale Campus     FL     5.0
# 163330  49146401          ABC Adult School - Cabrillo Lane     CA     8.0
#
#         ADM_RATE  TUITIONFEE_IN  Year
# 0            0.0            0.0  1996
# ...

# %%
# <6> 
# explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

final_df.shape
# Out:
# (163331, 7)

# %%
final_df.head()
# Out:
#    UNITID                                  INSTNM STABBR  REGION  ADM_RATE  \
# 0  100636      Community College of the Air Force     AL     0.0       0.0
# 1  100654                Alabama A & M University     AL     5.0       0.0
# 2  100663     University of Alabama at Birmingham     AL     5.0       0.0
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE     AL     5.0       0.0
# 4  100690                      Amridge University     AL     5.0       0.0
#
#    TUITIONFEE_IN  Year
# 0            0.0  1996
# 1            0.0  1996
# 2            0.0  1996
# 3            0.0  1996
# 4            0.0  1996

# %%
final_df.tail()
# Out:
#           UNITID                                    INSTNM STABBR  REGION  \
# 163326  48511112         Georgia Military College - Dublin     GA     5.0
# 163327  48511113        Georgia Military College - Eastman     GA     5.0
# 163328  48616901  American College of Barbering - Florence     KY     5.0
# 163329  49005401      HCI College - Fort Lauderdale Campus     FL     5.0
# 163330  49146401          ABC Adult School - Cabrillo Lane     CA     8.0
#
#         ADM_RATE  TUITIONFEE_IN  Year
# 163326       0.0         6120.0  2018
# 163327       0.0         6120.0  2018
# 163328       0.0            0.0  2018
# 163329       0.0        21420.0  2018
# 163330       0.0            0.0  2018

# %%
final_df.sample(5)
# Out:
#         UNITID                                          INSTNM STABBR  REGION  \
# 21891   144883                            East-West University     IL     3.0
# 137941  218858              Central Carolina Technical College     SC     5.0
# 4641    219596  Tennessee College of Applied Technology-Athens     TN     5.0
# 43252   183804                             Beth Medrash Govoha     NJ     2.0
# 79087   240709                           Cheeks Beauty Academy     WY     7.0
#
#         ADM_RATE  TUITIONFEE_IN  Year
# 21891        0.0            0.0  1999
# 137941       0.0         4481.0  2015
# 4641         0.0            0.0  1996
# 43252        0.0            0.0  2002
# 79087        0.0            0.0  2007

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163331 entries, 0 to 163330
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   UNITID         163331 non-null  int64
#  1   INSTNM         163331 non-null  object
#  2   STABBR         163331 non-null  object
#  3   REGION         163331 non-null  float64
#  4   ADM_RATE       163331 non-null  float64
#  5   TUITIONFEE_IN  163331 non-null  float64
#  6   Year           163331 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 8.7+ MB

# %%
final_df.describe(include="object")
# Out:
#                             INSTNM  STABBR
# count                       163331  163331
# unique                       11094      59
# top     Marinello School of Beauty      CA
# freq                           133   16193

# %%
final_df.describe(include="int64")
# Out:
#              UNITID           Year
# count  1.633310e+05  163331.000000
# mean   9.432395e+05    2007.249481
# std    4.571721e+06       6.608266
# min    1.006360e+05    1996.000000
# 25%    1.633380e+05    2002.000000
# 50%    2.127800e+05    2008.000000
# 75%    4.075680e+05    2013.000000
# max    4.914640e+07    2018.000000

# %%
final_df.describe(include="float64")
# Out:
#               REGION       ADM_RATE  TUITIONFEE_IN
# count  163331.000000  163331.000000  163331.000000
# mean        4.554665       0.190539    5656.232020
# std         2.189239       0.329672    9074.186783
# min         0.000000       0.000000       0.000000
# 25%         3.000000       0.000000       0.000000
# 50%         5.000000       0.000000       0.000000
# 75%         6.000000       0.375000    8852.500000
# max         9.000000       1.000000   74787.000000

# %%
# <7>
# the dataframe contains many years of data of all U.S. colleges.
# let's just look at UMBC
# filter/query the dataframe to retrieve only rows that belong to UMBC
# save the UMNC data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.

UMBC=final_df.loc[final_df["INSTNM"] == "University of Maryland-Baltimore County"]
UMBC
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# ...

# %%
# <8>
# Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

UMBC.shape
# Out:
# (23, 7)

# %%
UMBC.head()
# Out:
#        UNITID                                   INSTNM STABBR  REGION  \
# 2151   163268  University of Maryland-Baltimore County     MD     2.0
# 9056   163268  University of Maryland-Baltimore County     MD     2.0
# 15923  163268  University of Maryland-Baltimore County     MD     2.0
# 22598  163268  University of Maryland-Baltimore County     MD     2.0
# 29178  163268  University of Maryland-Baltimore County     MD     2.0
#
#        ADM_RATE  TUITIONFEE_IN  Year
# 2151        0.0            0.0  1996
# 9056        0.0            0.0  1997
# 15923       0.0            0.0  1998
# 22598       0.0            0.0  1999
# 29178       0.0         5490.0  2000

# %%
UMBC.tail()
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 128353  163268  University of Maryland-Baltimore County     MD     2.0
# 136064  163268  University of Maryland-Baltimore County     MD     2.0
# 143685  163268  University of Maryland-Baltimore County     MD     2.0
# 150891  163268  University of Maryland-Baltimore County     MD     2.0
# 157940  163268  University of Maryland-Baltimore County     MD     2.0
#
#         ADM_RATE  TUITIONFEE_IN  Year
# 128353    0.5961        10384.0  2014
# 136064    0.5942        11006.0  2015
# 143685    0.5683        11264.0  2016
# 150891    0.6021        11518.0  2017
# 157940    0.5794        11778.0  2018

# %%
UMBC.sample(5)
# Out:
#        UNITID                                   INSTNM STABBR  REGION  \
# 2151   163268  University of Maryland-Baltimore County     MD     2.0
# 62522  163268  University of Maryland-Baltimore County     MD     2.0
# 97506  163268  University of Maryland-Baltimore County     MD     2.0
# 29178  163268  University of Maryland-Baltimore County     MD     2.0
# 15923  163268  University of Maryland-Baltimore County     MD     2.0
#
#        ADM_RATE  TUITIONFEE_IN  Year
# 2151     0.0000            0.0  1996
# 62522    0.7143         8520.0  2005
# 97506    0.6589         9171.0  2010
# 29178    0.0000         5490.0  2000
# 15923    0.0000            0.0  1998

# %%
UMBC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 2151 to 157940
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UNITID         23 non-null     int64
#  1   INSTNM         23 non-null     object
#  2   STABBR         23 non-null     object
#  3   REGION         23 non-null     float64
#  4   ADM_RATE       23 non-null     float64
#  5   TUITIONFEE_IN  23 non-null     float64
#  6   Year           23 non-null     int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.4+ KB

# %%
UMBC.describe(include="float64")
# Out:
#        REGION   ADM_RATE  TUITIONFEE_IN
# count    23.0  23.000000      23.000000
# mean      2.0   0.501413    7438.782609
# std       0.0   0.274154    3860.898223
# min       2.0   0.000000       0.000000
# 25%       2.0   0.572000    6136.000000
# 50%       2.0   0.603500    8708.000000
# 75%       2.0   0.673950    9916.000000
# max       2.0   0.717400   11778.000000

# %%
UMBC.describe(include="object")
# Out:
#                                          INSTNM STABBR
# count                                        23     23
# unique                                        1      1
# top     University of Maryland-Baltimore County     MD
# freq                                         23     23

# %%
UMBC.describe(include="int64")
# Out:
#          UNITID        Year
# count      23.0    23.00000
# mean   163268.0  2007.00000
# std         0.0     6.78233
# min    163268.0  1996.00000
# 25%    163268.0  2001.50000
# 50%    163268.0  2007.00000
# 75%    163268.0  2012.50000
# max    163268.0  2018.00000

# %%
import matplotlib.pyplot as plt
ax = UMBC.plot.bar(x='Year',y= 'TUITIONFEE_IN', title ="UMBC's in-state tuition from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Tuition fees", fontsize=12)
plt.show()

# %%
# <10> 
# Plot UMBC's in-state tution overtime from 1996 to 2019 using Line Chart

ax = UMBC.plot.line(x='Year',y= 'TUITIONFEE_IN', title ="UMBC's in-state tuition from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Tuition fees", fontsize=12)
plt.show()

# %%
# <11>
# Now let's look at the tuition growth rate year over year
# We need to calculate UMBC tuition change percentage each year
# First convert the TUITIONFEE_IN column to a Python List

TUITIONFEE_IN_list = UMBC['TUITIONFEE_IN'].tolist()
print(TUITIONFEE_IN_list)
# Out:
# [0.0, 0.0, 0.0, 0.0, 5490.0, 5910.0, 6362.0, 7388.0, 8020.0, 8520.0, 8622.0, 8708.0, 8780.0, 8872.0, 9171.0, 9467.0, 9764.0, 10068.0, 10384.0, 11006.0, 11264.0, 11518.0, 11778.0]

# %%
T=TUITIONFEE_IN_list[4:] 
print(T)
# Out:
# [5490.0, 5910.0, 6362.0, 7388.0, 8020.0, 8520.0, 8622.0, 8708.0, 8780.0, 8872.0, 9171.0, 9467.0, 9764.0, 10068.0, 10384.0, 11006.0, 11264.0, 11518.0, 11778.0]

# %%
#next(i for i, j in enumerate(T) if j!=0)
# Out:
# 0

# %%
#for name in T:
    #if T[0]==0:
        #T[0]=T[next(i for i, j in enumerate(T) if j!=0)]
    #else:
        #T[0]=T[0]
#T[0]

# %%
#T=T[0:next(i for i, j in enumerate(T) if j!=0)]
T
# Out:
# []

# %%
# Loop through the list and calculate the % change each year over the prior year
# This takes some effort. Not hard, just some abstract/logical thinking and some experiments
# Have fun on this one

a=T[0]
Growth_rate=[]
for i in range (0, len(T)):
        rate=(T[i]-a)/a*100
        Growth_rate.append(rate)
print(Growth_rate, type(Growth_rate))
# Out:
# [0.0, 7.650273224043716, 15.883424408014571, 34.571948998178506, 46.083788706739526, 55.19125683060109, 57.049180327868854, 58.61566484517304, 59.92714025500911, 61.602914389799636, 67.04918032786885, 72.44080145719491, 77.85063752276868, 83.3879781420765, 89.14389799635701, 100.4735883424408, 105.17304189435337, 109.79963570127505, 114.53551912568305] <class 'list'>

# %%
# The resulting number has many decimal points which are unnecessary and not visually appealing.
# Round up the percentage to two decimal points
# You can use for loop. Or better, use list comprehension for simplicity/brevity

# %%
Growth_rate
# Out:
# [0.0,
#  7.650273224043716,
#  15.883424408014571,
#  34.571948998178506,
#  46.083788706739526,
#  55.19125683060109,
#  57.049180327868854,
#  58.61566484517304,
#  59.92714025500911,
#  61.602914389799636,
#  67.04918032786885,
#  72.44080145719491,
#  77.85063752276868,
#  83.3879781420765,
#  89.14389799635701,
#  100.4735883424408,
#  105.17304189435337,
#  109.79963570127505,
#  114.53551912568305]

# %%
Growth_rate = [float(i) for i in Growth_rate]   #we need to convert the elements of the list into a float because we have strings
Growth_rate = [round(num, 2) for num in Growth_rate]
print(Growth_rate)
# Out:
# [0.0, 7.65, 15.88, 34.57, 46.08, 55.19, 57.05, 58.62, 59.93, 61.6, 67.05, 72.44, 77.85, 83.39, 89.14, 100.47, 105.17, 109.8, 114.54]

# %%
# Add the list of the percentages to the dataframe as a new column ("PCT_CHANGE")
# Not as hard as you may think. If you get stuck, you think too hard. 
# Google it and you will find the answer.

PCT_CHANGE=[0,0,0,0]+Growth_rate
print(PCT_CHANGE)
UMBC['PCT_CHANGE']= PCT_CHANGE
UMBC
# Out:
# [0, 0, 0, 0, 0.0, 7.65, 15.88, 34.57, 46.08, 55.19, 57.05, 58.62, 59.93, 61.6, 67.05, 72.44, 77.85, 83.39, 89.14, 100.47, 105.17, 109.8, 114.54]
# <ipython-input-332-d36baac2b372>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UMBC['PCT_CHANGE']= PCT_CHANGE
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# ...

# %%
# Finaly, we can make the plot tuition growth rate year over year - bar first, then line chart

ax = UMBC.plot.bar(x='Year',y= 'PCT_CHANGE', title ="UMBC's Tuition growth rate from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Growth rate", fontsize=12)
plt.show()

# %%
# Finaly, we can make the plot tuition growth rate year over year - bar first, then line chart

ax = UMBC.plot.line(x='Year',y= 'PCT_CHANGE', title ="UMBC's Tuition growth rate from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Growth rate", fontsize=12)
plt.show()

# %%
# <12>
# Since we want to do the same calculation for JHU. 
# Instead of doing it piecemeal as we did for UMBC
# Let's create a function which can be reused for any college.
# This function takes a list of tuitions and return a list of percentage changes year over year
# This function can be used later 

def percent_list(school) :
    TUITIONFEE_IN_list = school['TUITIONFEE_IN'].tolist()  # column into a list
    T=TUITIONFEE_IN_list[4:]
    a=T[0]
    Growth_rate=[]
    for i in range (0, len(T)):
        rate=(T[i]-a)/a*100
        Growth_rate.append(rate) 
        Growth_rate = [float(i) for i in Growth_rate]
        Growth_rate = [round(num, 2) for num in Growth_rate]
    return (Growth_rate)

# %%
percent_list(UMBC)  #test of the function
# Out:
# [0.0,
#  7.65,
#  15.88,
#  34.57,
#  46.08,
#  55.19,
#  57.05,
#  58.62,
#  59.93,
#  61.6,
#  67.05,
#  72.44,
#  77.85,
#  83.39,
#  89.14,
#  100.47,
#  105.17,
#  109.8,
#  114.54]

# %%
# <13>
# the dataframe contains many years of data of all U.S. colleges.
# let's just look at JHU
# filter/query the dataframe to retrieve only rows that belong to JHU
# save the JHU data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.

JHU=final_df.loc[final_df["INSTNM"] == "Johns Hopkins University"]
JHU
# Out:
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139    162928  Johns Hopkins University     MD     2.0    0.0000
# 9046    162928  Johns Hopkins University     MD     2.0    0.0000
# 15914   162928  Johns Hopkins University     MD     2.0    0.0000
# 22589   162928  Johns Hopkins University     MD     2.0    0.0000
# 29169   162928  Johns Hopkins University     MD     2.0    0.0000
# 35812   162928  Johns Hopkins University     MD     2.0    0.3431
# 42515   162928  Johns Hopkins University     MD     2.0    0.3506
# 49148   162928  Johns Hopkins University     MD     2.0    0.3060
# 55779   162928  Johns Hopkins University     MD     2.0    0.3071
# 62515   162928  Johns Hopkins University     MD     2.0    0.3509
# 69394   162928  Johns Hopkins University     MD     2.0    0.2792
# 76325   162928  Johns Hopkins University     MD     2.0    0.2571
# 83284   162928  Johns Hopkins University     MD     2.0    0.2609
# ...

# %%
# <14> 
# Plot JHU's in-state tuition overtime from 1996 to 2019. 
# Let's plot bar and line chart together

ax = JHU.plot.bar(x='Year',y= 'TUITIONFEE_IN', title ="JHU's in-state tuition from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Tuition fees", fontsize=12)
plt.show()

# %%
ax = JHU.plot.line(x='Year',y= 'TUITIONFEE_IN', title ="JHU's in-state tuition from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Tuition fees", fontsize=12)
plt.show()

# %%
# <15>
# Let's calculate the JHU tuition percentge growth using the function defined earlier

PCT_CHANGE=percent_list(JHU)
PCT_CHANGE
# Out:
# [0.0,
#  5.13,
#  9.87,
#  15.24,
#  20.9,
#  26.84,
#  35.98,
#  44.0,
#  51.22,
#  57.04,
#  63.18,
#  69.59,
#  74.05,
#  82.39,
#  88.77,
#  95.39,
#  102.21,
#  109.27,
#  115.56]

# %%
# <16>
# Add the list of percentage changes to the dataframe as a new column ("PCT_CHANGE")

PCT_CHANGE=[0,0,0,0]+PCT_CHANGE
PCT_CHANGE
# Out:
# [0,
#  0,
#  0,
#  0,
#  0.0,
#  5.13,
#  9.87,
#  15.24,
#  20.9,
#  26.84,
#  35.98,
#  44.0,
#  51.22,
#  57.04,
#  63.18,
#  69.59,
#  74.05,
#  82.39,
#  88.77,
#  95.39,
#  102.21,
#  109.27,
#  115.56]

# %%
JHU['PCT_CHANGE']= PCT_CHANGE
JHU
# Out:
# <ipython-input-342-0946e916dea7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JHU['PCT_CHANGE']= PCT_CHANGE
#         UNITID                    INSTNM STABBR  REGION  ADM_RATE  \
# 2139    162928  Johns Hopkins University     MD     2.0    0.0000
# 9046    162928  Johns Hopkins University     MD     2.0    0.0000
# 15914   162928  Johns Hopkins University     MD     2.0    0.0000
# 22589   162928  Johns Hopkins University     MD     2.0    0.0000
# 29169   162928  Johns Hopkins University     MD     2.0    0.0000
# 35812   162928  Johns Hopkins University     MD     2.0    0.3431
# 42515   162928  Johns Hopkins University     MD     2.0    0.3506
# 49148   162928  Johns Hopkins University     MD     2.0    0.3060
# ...

# %%
# <17> Make a bar plot of the JHU percentage changes tuitions over time

ax = JHU.plot.bar(x='Year',y= 'PCT_CHANGE', title ="JHU's Tuition growth rate from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Growth rate", fontsize=12)
plt.show()

# %%
UMBC
# Out:
#         UNITID                                   INSTNM STABBR  REGION  \
# 2151    163268  University of Maryland-Baltimore County     MD     2.0
# 9056    163268  University of Maryland-Baltimore County     MD     2.0
# 15923   163268  University of Maryland-Baltimore County     MD     2.0
# 22598   163268  University of Maryland-Baltimore County     MD     2.0
# 29178   163268  University of Maryland-Baltimore County     MD     2.0
# 35821   163268  University of Maryland-Baltimore County     MD     2.0
# 42524   163268  University of Maryland-Baltimore County     MD     2.0
# 49156   163268  University of Maryland-Baltimore County     MD     2.0
# 55786   163268  University of Maryland-Baltimore County     MD     2.0
# 62522   163268  University of Maryland-Baltimore County     MD     2.0
# 69401   163268  University of Maryland-Baltimore County     MD     2.0
# 76332   163268  University of Maryland-Baltimore County     MD     2.0
# ...

# %%
# <18>
# In order to plot both UMBC and JHU tuition change over time in the same plot,
# we need to combine the two datasets using the common key of YEAR 
# First make a umbc2 dataframe with only two columns needed. WE don't need other columns.
# Also change the column name from "PCT_CHANGE" to "UMBC_PCT" in preparation for the merge.
# This is because both umbc and jhu dataframe have the same column name "PCT_CHANGE",
# We rename them to there is no collision during the merge. BTW, Pandas handles collision gracefully,
# Feel free to try it without changing the column names.

UMBC = UMBC[["PCT_CHANGE", "Year"]]

UMBC
# Out:
#         PCT_CHANGE  Year
# 2151          0.00  1996
# 9056          0.00  1997
# 15923         0.00  1998
# 22598         0.00  1999
# 29178         0.00  2000
# 35821         7.65  2001
# 42524        15.88  2002
# 49156        34.57  2003
# 55786        46.08  2004
# 62522        55.19  2005
# 69401        57.05  2006
# 76332        58.62  2007
# 83291        59.93  2008
# 90324        61.60  2009
# 97506        67.05  2010
# 104960       72.44  2011
# 112672       77.85  2012
# 120503       83.39  2013
# 128353       89.14  2014
# 136064      100.47  2015
# 143685      105.17  2016
# 150891      109.80  2017
# 157940      114.54  2018

# %%
UMBC.columns = ['UMBC_PCT', 'Year']
UMBC
# Out:
#         UMBC_PCT  Year
# 2151        0.00  1996
# 9056        0.00  1997
# 15923       0.00  1998
# 22598       0.00  1999
# 29178       0.00  2000
# 35821       7.65  2001
# 42524      15.88  2002
# 49156      34.57  2003
# 55786      46.08  2004
# 62522      55.19  2005
# 69401      57.05  2006
# 76332      58.62  2007
# 83291      59.93  2008
# 90324      61.60  2009
# 97506      67.05  2010
# 104960     72.44  2011
# 112672     77.85  2012
# 120503     83.39  2013
# 128353     89.14  2014
# 136064    100.47  2015
# 143685    105.17  2016
# 150891    109.80  2017
# 157940    114.54  2018

# %%
# Then make a jhu2 dataframe with only two columns needed. WE don't need other columns.
# Also change the column name from "PCT_CHANGE" to "JHU_PCT"  in preparation for the merge

JHU = JHU[["PCT_CHANGE", "Year"]]

JHU
# Out:
#         PCT_CHANGE  Year
# 2139          0.00  1996
# 9046          0.00  1997
# 15914         0.00  1998
# 22589         0.00  1999
# 29169         0.00  2000
# 35812         5.13  2001
# 42515         9.87  2002
# 49148        15.24  2003
# 55779        20.90  2004
# 62515        26.84  2005
# 69394        35.98  2006
# 76325        44.00  2007
# 83284        51.22  2008
# 90317        57.04  2009
# 97499        63.18  2010
# 104953       69.59  2011
# 112665       74.05  2012
# 120496       82.39  2013
# 128346       88.77  2014
# 136057       95.39  2015
# 143678      102.21  2016
# 150886      109.27  2017
# 157935      115.56  2018

# %%
JHU.columns = ['JHU_PCT', 'Year']
JHU
# Out:
#         JHU_PCT  Year
# 2139       0.00  1996
# 9046       0.00  1997
# 15914      0.00  1998
# 22589      0.00  1999
# 29169      0.00  2000
# 35812      5.13  2001
# 42515      9.87  2002
# 49148     15.24  2003
# 55779     20.90  2004
# 62515     26.84  2005
# 69394     35.98  2006
# 76325     44.00  2007
# 83284     51.22  2008
# 90317     57.04  2009
# 97499     63.18  2010
# 104953    69.59  2011
# 112665    74.05  2012
# 120496    82.39  2013
# 128346    88.77  2014
# 136057    95.39  2015
# 143678   102.21  2016
# 150886   109.27  2017
# 157935   115.56  2018

# %%
# Now, merger the two data frames
# and display the new dataframe

#(Write code here)

Final_merge=pd.merge(UMBC, JHU, how='outer')
Final_merge
# Out:
#     UMBC_PCT  Year  JHU_PCT
# 0       0.00  1996     0.00
# 1       0.00  1997     0.00
# 2       0.00  1998     0.00
# 3       0.00  1999     0.00
# 4       0.00  2000     0.00
# 5       7.65  2001     5.13
# 6      15.88  2002     9.87
# 7      34.57  2003    15.24
# 8      46.08  2004    20.90
# 9      55.19  2005    26.84
# 10     57.05  2006    35.98
# 11     58.62  2007    44.00
# 12     59.93  2008    51.22
# 13     61.60  2009    57.04
# 14     67.05  2010    63.18
# 15     72.44  2011    69.59
# 16     77.85  2012    74.05
# 17     83.39  2013    82.39
# 18     89.14  2014    88.77
# 19    100.47  2015    95.39
# 20    105.17  2016   102.21
# 21    109.80  2017   109.27
# 22    114.54  2018   115.56

# %%
#Plot them together using y=["UMBC_PCT","JHU_PCT"] option of bar plot

ax = Final_merge.plot.bar(x='Year',y=["UMBC_PCT","JHU_PCT"], title ="JHU's Tuition growth rate from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Growth rate", fontsize=12)
plt.show()

# %%
# Plot them together using y=["UMBC_PCT","JHU_PCT"] option of line plot

ax = Final_merge.plot.line(x='Year',y=["UMBC_PCT","JHU_PCT"], title ="JHU's Tuition growth rate from 1996 to 2019", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Growth rate", fontsize=12)
plt.show()

# %%
# <19> 
# document your observation/conclusion of the comparison plots (bar/line)
# use the following Markdown cell

# %% [markdown]
# Based on my observation of the plots, the growth rate of UMBC were speeder and higher than JHU's growth rate until 2018. The JHU's growth over the years is linear and the speed seems constant.
# Over 19 years, JHU has a higher growth rate than that of UMBC
