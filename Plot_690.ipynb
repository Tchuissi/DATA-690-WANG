# %% [markdown]
# <a href="https://colab.research.google.com/github/Tchuissi/DATA-690-WANG/blob/master/Plot_690.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig.show()

# %%
fig, ax_list = plt.subplots(2,2,figsize=(8,6))
fig.show()

# %%
type(ax_list)
# Out:
# numpy.ndarray

# %%
ax_list.shape
# Out:
# (2, 2)

# %%
x=[1,2,3,4]
y=[10,15.5, -12, 34]

fig, ax_list=plt.subplots(2,2, figsize=(8,6))
ax_list[0,0].plot(x,y)
fig.show()
